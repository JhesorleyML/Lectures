# %% [markdown]
# ### JHESORLEY M. LAID
# ### MIT-2

# %%
import random

# %%
def reservoir_sampling(stream, k ):
    reservoir = []

# %%
k = 10

# %%
reservoir = []

# %%
stream = list(range(1, 1000))

# %%
    for i in range(k):
        reservoir.append(stream[i])

# %%
 for i in range(k, len(stream)):
        j = random.randint(0, i)
        if j < k:
            reservoir[j] = stream[i]

# %%
reservoir
# Out:
# [621, 845, 178, 436, 943, 559, 636, 237, 741, 160]
